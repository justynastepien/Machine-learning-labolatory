# %%
import tensorflow_datasets as tfds
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from functools import partial
import pickle

# %%
[test_set_raw, valid_set_raw, train_set_raw], info = tfds.load(
    "tf_flowers",
    split=["train[:10%]", "train[10%:25%]", "train[25%:]"],
    as_supervised = True,
    with_info = True)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling ~\tensorflow_datasets\tf_flowers\3.0.1.incomplete9V9YUF\tf_flowers-train.tfrecord*...:   0%|        …
# Dataset tf_flowers downloaded and prepared to ~\tensorflow_datasets\tf_flowers\3.0.1. Subsequent calls will reuse this data.

# %%
class_names = info.features["label"].names
n_classes = info.features["label"].num_classes
dataset_size = info.splits["train"].num_examples

# %%
plt.figure(figsize=(12,8))
index = 0
sample_images = train_set_raw.take(9)
for image, label in sample_images:
    index += 1
    plt.subplot(3, 3, index)
    plt.imshow(image)
    plt.title("Class: {}".format(class_names[label]))
    plt.axis("off")
    
plt.show(block=False)

# %%
def preprocess(image, label):
    resized_image = tf.image.resize(image, [224, 224])
    return resized_image, label

# %%
batch_size = 32
train_set = train_set_raw.map(preprocess).shuffle(dataset_size).batch(batch_size).prefetch(1)
valid_set = valid_set_raw.map(preprocess).batch(batch_size).prefetch(1)
test_set = test_set_raw.map(preprocess).batch(batch_size).prefetch(1)

# %%
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
plt.figure(figsize = (8, 8))
sample_batch = train_set.take(1)
for X_batch, y_batch in sample_batch:
    for index in range(12):
        plt.subplot(3, 4, index + 1)
        plt.imshow(X_batch[index]/255.0)
        plt.title("Class: {}".format(class_names[y_batch[index]]))
        plt.axis("off")

plt.show()

# %%
DefaultConv2D=partial(keras.layers.Conv2D, kernel_size=3, activation='relu', padding="SAME")

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Rescaling(scale = 1/127.5, offset=-1))
model.add(DefaultConv2D(filters=64, kernel_size=7, input_shape=[28,28,1]))
model.add(keras.layers.MaxPooling2D(pool_size=2))
model.add(DefaultConv2D(filters=128))
model.add(DefaultConv2D(filters=128))
model.add(keras.layers.MaxPooling2D(pool_size=2))
model.add(DefaultConv2D(filters=256))
model.add(DefaultConv2D(filters=256))
model.add(keras.layers.MaxPooling2D(pool_size=2))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(units=128, activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(units=10, activation='softmax'))

# %%
model.compile(loss = "sparse_categorical_crossentropy", optimizer = "sgd", metrics = ['accuracy'])

# %%
model.fit(train_set, validation_data=valid_set, epochs = 10)
# Out:
# Epoch 1/10
# 86/86 [==============================] - 612s 7s/step - loss: 1.7534 - accuracy: 0.2522 - val_loss: 1.4303 - val_accuracy: 0.4065
# Epoch 2/10
# 86/86 [==============================] - 621s 7s/step - loss: 1.4017 - accuracy: 0.4041 - val_loss: 1.1740 - val_accuracy: 0.5136
# Epoch 3/10
# 86/86 [==============================] - 623s 7s/step - loss: 1.2499 - accuracy: 0.4884 - val_loss: 1.1774 - val_accuracy: 0.5318
# Epoch 4/10
# 86/86 [==============================] - 632s 7s/step - loss: 1.1905 - accuracy: 0.5105 - val_loss: 1.0915 - val_accuracy: 0.5263
# Epoch 5/10
# 86/86 [==============================] - 623s 7s/step - loss: 1.1428 - accuracy: 0.5316 - val_loss: 1.1770 - val_accuracy: 0.5172
# Epoch 6/10
# 86/86 [==============================] - 640s 7s/step - loss: 1.1129 - accuracy: 0.5545 - val_loss: 1.0658 - val_accuracy: 0.5753
# Epoch 7/10
# ...

# %%
acc_train = model.history.history.get('accuracy')
acc_train.reverse()
print(acc_train[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23840/3098925317.py in <module>
#       1 acc_train = model.history.history.get('accuracy')
# ----> 2 acc_train.reverse()
#       3 print(acc_train[0])
#
# AttributeError: 'NoneType' object has no attribute 'reverse'

# %%
acc_test = model.evaluate(test_set)
print[acc_test[1]]
# Out:
# 12/12 [==============================] - 51s 4s/step - loss: 0.9693 - accuracy: 0.6267
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23840/1461609277.py in <module>
#       1 acc_test = model.evaluate(test_set)
# ----> 2 print[acc_test[1]]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
acc_valid = model.history.history.get('val_accuracy')
acc_valid.reverse()
print(acc_valid[0])

#(acc_train, acc_valid, acc_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23840/2637237352.py in <module>
#       1 acc_train = model.history.history.get('accuracy')
#       2 #acc_train.reverse()
# ----> 3 print(acc_train[0])
#       4
#       5 acc_test = model.evaluate(test_set)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
krot1 = (acc_train[0], acc_valid[0], acc_test[1])
f1 = open("simple_cnn_acc.pkl", "wb")
pickle.dump(krot1, f1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23840/4100560547.py in <module>
# ----> 1 krot1 = (acc_train[0], acc_valid[0], acc_test[1])
#       2 f1 = open("simple_cnn_acc.pkl", "wb")
#       3 pickle.dump(krot1, f1)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
def preprocess(image, label):
    resized_image = tf.image.resize(image, [224, 224])
    final_image = tf.keras.applications.xception.preprocess_input(resized_image)
    return final_image, label

# %%
plt.figure(figsize=(8, 8))
sample_batch = train_set.take(1)
for X_batch, y_batch in sample_batch:
    for index in range(12):
        plt.subplot(3, 4, index + 1)
        plt.imshow(X_batch[index] / 2 + 0.5)
        plt.title("Class: {}".format(class_names[y_batch[index]]))
        plt.axis("off")
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
base_model = tf.keras.applications.xception.Xception(
weights="imagenet",
include_top=False)
# Out:
# ...
# 83697664/83683744 [==============================] - 1s 0us/step

# %%
for index, layer in enumerate(base_model.layers):
    print(index, layer.name)
# Out:
# 0 input_1
# 1 block1_conv1
# 2 block1_conv1_bn
# 3 block1_conv1_act
# 4 block1_conv2
# 5 block1_conv2_bn
# 6 block1_conv2_act
# 7 block2_sepconv1
# 8 block2_sepconv1_bn
# 9 block2_sepconv2_act
# 10 block2_sepconv2
# 11 block2_sepconv2_bn
# 12 conv2d_20
# 13 block2_pool
# 14 batch_normalization
# 15 add
# 16 block3_sepconv1_act
# 17 block3_sepconv1
# 18 block3_sepconv1_bn
# 19 block3_sepconv2_act
# 20 block3_sepconv2
# 21 block3_sepconv2_bn
# 22 conv2d_21
# 23 block3_pool
# 24 batch_normalization_1
# 25 add_1
# 26 block4_sepconv1_act
# 27 block4_sepconv1
# 28 block4_sepconv1_bn
# 29 block4_sepconv2_act
# 30 block4_sepconv2
# 31 block4_sepconv2_bn
# 32 conv2d_22
# 33 block4_pool
# 34 batch_normalization_2
# 35 add_2
# 36 block5_sepconv1_act
# 37 block5_sepconv1
# 38 block5_sepconv1_bn
# 39 block5_sepconv2_act
# 40 block5_sepconv2
# 41 block5_sepconv2_bn
# 42 block5_sepconv3_act
# 43 block5_sepconv3
# 44 block5_sepconv3_bn
# 45 add_3
# 46 block6_sepconv1_act
# 47 block6_sepconv1
# ...

# %%
avg = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
output = tf.keras.layers.Dense(units=128, activation='softmax')(avg)

# %%
modelv2 = tf.keras.Model(inputs=base_model.input, outputs=output)
optimizer = tf.keras.optimizers.SGD(learning_rate=0.2, momentum=0.9,decay=0.01)
modelv2.compile(loss = "sparse_categorical_crossentropy", optimizer = optimizer, metrics = ['accuracy'])

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
history = modelv2.fit(train_set, validation_data=valid_set, epochs = 5)
# Out:
# 12/12 [==============================] - 152s 13s/step - loss: 0.1413 - accuracy: 0.9619 - val_loss: 0.4590 - val_accuracy: 0.8730

# %%
for layer in base_model.layers:
    layer.trainable = True

# %%
modelv2.fit(train_set, validation_data=valid_set, epochs = 10)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23840/220107716.py in <module>
# ----> 1 modelv2.fit(train_set, validation_data=valid_set, epochs = 10)
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
# ...

# %%
#lista1 = modelv2.evaluate(test_set)

acc_train = modelv2.history.history.get('accuracy')
acc_train.reverse()
print(acc_train[0])
#(acc_train, acc_valid, acc_test)
# Out:
# 0.9618528485298157

# %%
acc_test = modelv2.evaluate(test_set)
acc_test[1]
# Out:
# 12/12 [==============================] - 23s 2s/step - loss: 0.1577 - accuracy: 0.9455
# 0.9455040693283081

# %%
acc_valid = modelv2.history.history.get('val_accuracy')
acc_valid.reverse()
print(acc_valid[0])
# Out:
# 0.872958242893219

# %%
krot2 = (acc_train[0], acc_valid[0], acc_test[1])
f2 = open("xception_acc.pkl", "wb")
pickle.dump(krot2, f2)
